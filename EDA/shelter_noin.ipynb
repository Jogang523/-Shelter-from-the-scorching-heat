# %%
import pandas as pd
shelter=pd.read_csv('C:/Users/M/Downloads/project/data/무더위 쉼터 장소 정보.csv')
shelter['이용가능인원'] = shelter['이용가능인원'].str.extract('(\d+)')
shelter['capacity'] = shelter['이용가능인원'].astype(int)
shelter['gu'] = shelter['주소'].apply(lambda x: x.split()[1])
grouped_data = shelter.groupby('gu')['capacity'].sum().reset_index()

grouped_data
# Out:
#       gu  capacity
# 0    강남구      1747
# 1    강동구     11532
# 2    강북구      2216
# 3    강서구      7109
# 4    관악구      2304
# 5    광진구      3333
# 6    구로구     11255
# 7    금천구      2422
# 8    노원구      2920
# 9    도봉구      4904
# 10  동대문구      3851
# 11   동작구      4414
# 12   마포구      3094
# 13  서대문구      1661
# 14   서초구      1307
# 15   성동구      1909
# 16   성북구      9705
# 17   송파구      3329
# 18   양천구      7426
# 19  영등포구      3077
# 20   용산구      2994
# 21   은평구      2146
# 22   종로구      4162
# 23    중구      3497
# 24   중랑구      4564

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
plt.figure(figsize=(10,8))
plt.bar(grouped_data['gu'] , grouped_data['capacity'])
plt.xlabel('구별')
plt.xticks(rotation = 45)
plt.ylabel('수용인원')
plt.title('서울특별시 구별 무더위 쉼터 수용인원')
plt.savefig('C:/Users/M/Downloads/project/data/구별수용인원.png', dpi = 300)
